# %%
import numpy as np
matrix = [[1, 2, 3, 4], [1, 2, 3, 4]]

# %%
matrix_np = np.array(matrix)
matrix_dist = np.exp(matrix_np) / np.sum(matrix_np)

dist = np.matmul(matrix_dist.transpose(), np.array([1, 2]))
print(dist)
print(random.choice(dist))
# Out:
# [0.40774227 1.10835841 3.01283054 8.1897225 ]
# 1.1083584148395977

# %%
from kaggle_environments import make
import json
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
# 12x12: seed 562124211
# 32x32: seed 562124210
# 'episodeSteps':5
env = make("lux_ai_2021", configuration={"seed": 562124210, "loglevel": 2, "annotations": True}, debug=True)


# run a match between two agents
# current agents: simple, do_nothing, working_title, imitation_learning
agent0 = 'working_title'
agent1 = 'imitation_learning'

# steps = env.run(["./%s/agent.py" % agent0, "./%s/agent.py" % agent1])
# steps = env.run(['./rl_agent/main.py', './working_title/agent.py'])
steps = env.run(["agent.py", "agent.py"])
#steps = env.run(["./imitation_learning/agent.py", "./working_title/agent.py"])
# steps = env.run(["./rl_agent/main.py", "./rl_agent/main.py"])
# Out:
# rew/r_total=1.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=13.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=17.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=17.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=19.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=19.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=22.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=22.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=23.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=23.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=25.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=25.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=30.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=30.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=31.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=31.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=32.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=32.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=33.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=33.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=37.15,rew/r_wood=0.00,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.00,rew/r_city_tiles_end=37.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=0.00,game/research=0.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=0.00,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/4z/7rrlsr756fjg6jq7c4jy9fzc0000gn/T/ipykernel_6007/4210859889.py in <module>
#      12 # steps = env.run(["./%s/agent.py" % agent0, "./%s/agent.py" % agent1])
#      13 # steps = env.run(['./rl_agent/main.py', './working_title/agent.py'])
# ---> 14 steps = env.run(["agent.py", "agent.py"])
#      15 #steps = env.run(["./imitation_learning/agent.py", "./working_title/agent.py"])
#      16 # steps = env.run(["./rl_agent/main.py", "./rl_agent/main.py"])
#
# /opt/anaconda3/lib/python3.7/site-packages/kaggle_environments/core.py in run(self, agents)
#     232         start = perf_counter()
#     233         while not self.done and perf_counter() - start < self.configuration.runTimeout:
# --> 234             actions, logs = runner.act()
#     235             self.step(actions, logs)
#     236         return self.steps
#
# /opt/anaconda3/lib/python3.7/site-packages/kaggle_environments/core.py in act(none_action)
#     643                 results = self.pool.map(act_agent, act_args)
#     644             else:
# --> 645                 results = list(map(act_agent, act_args))
#     646
#     647             # results is a list of tuples where the first element is an agent action and the second is the agent log
#
# /opt/anaconda3/lib/python3.7/site-packages/kaggle_environments/core.py in act_agent(args)
#      99         return none_action, {}
#     100     else:
# --> 101         return agent.act(state["observation"])
#     102
#     103
#
# /opt/anaconda3/lib/python3.7/site-packages/kaggle_environments/agent.py in act(self, observation)
#     155             try:
#     156                 start = perf_counter()
# --> 157                 action = self.agent(*args)
#     158             except Exception as e:
#     159                 traceback.print_exc(file=err_buffer)
#
# /opt/anaconda3/lib/python3.7/site-packages/kaggle_environments/agent.py in callable_agent(observation, configuration)
#     127         return \
#     128             agent(*args) \
# --> 129             if callable(agent) \
#     130             else agent
#     131
#
# ~/code/lux_ai_kaggle/code/agent.py in agent(observation, configuration)
#     297     ### AI Code goes down here! ###
#     298     # player = observation.player
# --> 299     actions = meta_bot.run(observation)
#     300
#     301     return actions
#
# ~/code/lux_ai_kaggle/code/agent.py in run(self, observation)
#     235
#     236         for i, exp in enumerate(self.experts):
# --> 237             units, probabilities, city_actions = exp(observation, None, calc_actions=True, stochastic_actions=True)
#     238             for i, unit in enumerate(units):
#     239                 if unit not in self.unit_actions:
#
# ~/code/lux_ai_kaggle/code/kaban/agent_rl.py in agent_rl(observation, configuration, calc_actions, stochastic_actions)
#     130     global game_state
#     131
# --> 132     game_state = get_game_state(observation)
#     133     if not calc_actions:
#     134         return(None)
#
# ~/code/lux_ai_kaggle/code/kaban/agent_rl.py in get_game_state(observation)
#     100         game_state.id = observation["player"]
#     101     else:
# --> 102         game_state._update(observation["updates"])
#     103     return game_state
#     104
#
# ~/code/lux_ai_kaggle/code/kaban/lux/game.py in _update(self, messages)
#      35         update state
#      36         """
# ---> 37         self.map = GameMap(self.map_width, self.map_height)
#      38         self.turn += 1
#      39         self._reset_player_states()
#
# ~/code/lux_ai_kaggle/code/kaban/lux/game_map.py in __init__(self, width, height)
#      32             self.map[y] = [None] * width
#      33             for x in range(0, self.width):
# ---> 34                 self.map[y][x] = Cell(x, y)
#      35
#      36     def get_cell_by_pos(self, pos) -> Cell:
#
# KeyboardInterrupt:

# %%
env.render(mode="ipython", width=980, height=800)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;5f0e91cc-4cd1-11ec-ac42-acde48001122&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 562124210,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 32,
#             &quot;height&quot;: 32,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;32 32&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 29 316&quot;,
#               &quot;r wood 1 24 342&quot;,
#               &quot;r wood 1 25 323&quot;,
#               &quot;r uranium 1 31 332&quot;,
#               &quot;r wood 2 24 329&quot;,
#               &quot;r wood 2 25 397&quot;,
#               &quot;r wood 2 26 364&quot;,
#               &quot;r uranium 2 31 346&quot;,
#               &quot;r wood 3 28 800&quot;,
#               &quot;r wood 4 10 318&quot;,
#               &quot;r wood 4 11 398&quot;,
#               &quot;r uranium 4 17 336&quot;,
#               &quot;r wood 4 27 800&quot;,
#               &quot;r wood 4 28 800&quot;,
#               &quot;r wood 5 10 308&quot;,
#               &quot;r wood 5 11 326&quot;,
#               &quot;r uranium 5 17 335&quot;,
#               &quot;r coal 7 31 355&quot;,
#               &quot;r coal 8 0 369&quot;,
#               &quot;r coal 8 30 404&quot;,
#               &quot;r coal 8 31 422&quot;,
#               &quot;r wood 11 23 317&quot;,
#               &quot;r wood 11 24 330&quot;,
#               &quot;r wood 11 25 314&quot;,
#               &quot;r wood 12 23 349&quot;,
#               &quot;r wood 12 24 390&quot;,
#               &quot;r wood 13 6 337&quot;,
#               &quot;r wood 13 7 325&quot;,
#               &quot;r wood 13 24 374&

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('chosen_agent.log', names=['agent', 'raw_reward', 'scaled_reward'], skiprows=2)

color_dict = {2:['red', 'blue'],
              3:['red', 'blue', 'green'],
              4:['red', 'blue', 'green', 'orange'],
              5:['red', 'blue', 'green', 'orange', 'yellow']}

colors = color_dict[df['agent'].nunique()]


plt.figure(figsize=(15,15))
for (name, group), color in zip(df.groupby(['agent']), colors):
    plt.scatter(group.index, group['raw_reward'], s=1, c=color, label=name)
plt.legend()

# %%
df
# Out:
#                   agent     raw_reward scaled_reward
# 0    imitation_learning  working_title         kaban
# 1         working_title         1.1525      0.002305
# 2    imitation_learning            1.0         0.002
# 3                 kaban            1.0         0.002
# 4         working_title            1.0         0.002
# ..                  ...            ...           ...
# 355       working_title          192.0         0.384
# 356       working_title          192.0         0.384
# 357  imitation_learning          192.0         0.384
# 358  imitation_learning          192.0         0.384
# 359       working_title          192.0         0.384
#
# [360 rows x 3 columns]

# %%
with open('chosen_agent.log', 'r') as f:
    algo = f.readline().rstrip()
    agents = f.readline().rstrip()
print('Online learning algo: ', algo)
print('Agents: ', agents)
print('\nValue counts:')
print(df['agent'].value_counts())
print('Max raw reward: ', df['raw_reward'].max())
# Out:
# Online learning algo:  EXP4
# Agents:  imitation_learning,working_title,kaban
#
# Value counts:
# working_title         131
# imitation_learning    114
# kaban                 114
# Name: agent, dtype: int64
# Max raw reward:  192.8

# %%
# %debug

# %%
raise

# %%
# save replay
replay = env.toJSON()
with open("replay.json", "w") as f:
    json.dump(replay, f)

# %%
# to create .tar.gz submission (edit first line to cd into folder/agent to submit):

# !tar -czf submission.tar.gz main.py agent.py reward.py rl_agent imitation_learning working_title kaban __init__.py
